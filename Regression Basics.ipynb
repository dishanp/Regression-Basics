# %% [markdown]
# # Regression Basics
# ### By Dishan Purkayastha

# %%
import pandas as pd;
import numpy as numpy;
from scipy import stats;
import matplotlib.pyplot as plt;
from sklearn.metrics import r2_score;
from sklearn import linear_model;

# %% [markdown]
# Mean, Median, Mode, Variance & Standard Deviance

# %%
data = [32,111,138,28,59,77,97]
x=numpy.mean(data);
print(x);
# Out:
# 77.42857142857143

# %%
data = [32,111,138,28,59,77,97]
x=numpy.median(data);
print(x);
# Out:
# 77.0

# %%
data = [32,111,138,28,59,77,97,32,3]
x=stats.mode(data);
print(x);
# Out:
# ModeResult(mode=array([32]), count=array([2]))

# %%
data = [32,111,138,28,59,77,97]
x=numpy.var(data);
print(x);
# Out:
# 1432.2448979591834

# %%
data = [32,111,138,28,59,77,97]
x=numpy.std(data);
print(x);
# Out:
# 37.84501153334721

# %% [markdown]
# Generating Random Datasets & Corresponding Plots

# %%
#Uniform Distribution between 0 and 10 with 30 data points

x=numpy.random.uniform(0,10,30)
print(x)
# Out:
# [7.6948714  3.10310861 6.17385719 3.31480272 0.34989439 3.05146512
#  5.27907142 8.52786897 3.96887306 1.49587614 2.0937371  2.37129555
#  6.55602245 0.73469364 7.45846933 3.96303389 6.78924394 4.51651178
#  7.94821839 2.051052   3.16080403 0.8846236  8.34742915 0.46136309
#  8.23191508 7.57749322 1.95242424 6.67797559 1.1947566  1.9019593 ]

# %%
#Plotting the uniform data

plt.hist(x,10);
plt.show();

# %%
#Normal Distribution between 0 and 10 with 100 data points

x=numpy.random.normal(0,10,100)
print(x)
# Out:
# [ -3.11674596 -30.17156617  -7.19416664 -12.6262036    6.65151383
#    9.72905262  -2.78809372  -5.35187632  -1.7130325   -2.69303945
#   10.5319472    4.19279443  -5.01197452   9.3745256    3.46759299
#    4.44804175 -10.44493283  -7.60052571   5.31916551  12.7967009
#   -7.74422354  -2.19081371  -9.01430225   1.61308013   7.17127909
#    9.86191658  11.98610525 -15.54907094   0.36670794 -22.128761
#    4.88875352  -5.676252     2.30685602  28.20215823  11.39764089
#    6.34812447 -15.24786178   2.56094176   7.00226551  -9.54957183
#   -0.75859733  -9.04512171  -4.81099165   0.96761752 -21.01880571
#  -11.72487556  -9.1967052   14.41319019  -0.91100968   0.03526087
#   -2.80452486  16.99979602 -13.86433641   9.74370756  14.56047557
#  -11.97047358   2.36932072 -19.03917482   0.12501455  -2.03386636
#    7.69883822  -5.64709778   1.68148154   9.31784878  -9.14464522
#    3.14443687  -8.80886398   0.74922608   5.83809371   6.21244422
#   22.91489777   4.4708556  -17.07239734  10.13039871  -9.80650668
#    5.23569773   1.22703078   5.49153956  15.81418465   5.89980074
#   -2.803772   -19.38068546   3.013571     9.75838432  -0.36248027
#    2.16709723  -5.73925513   9.08059324   9.41731404   6.00594279
#   -2.40457128  10.90516851  12.86287186   1.16674707   4.92385476
#   -2.75250816   6.39816222   6.10035274  14.23540627  -3.50272047]

# %%
#Plotting the normal data

plt.hist(x,10);
plt.show();

# %%
#Scatter Plot

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x,y)

# %%
# Random Scatter Plot for bigger data set

x=numpy.random.uniform(0,10,300);
y=numpy.random.uniform(50,100,300);
plt.scatter(x,y);

# %% [markdown]
# Linear Regression

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope,intercept,r,p,std_err = stats.linregress(x,y)

def myfunc(x):
    return slope*x + intercept

mymodel=list(map(myfunc,x))

plt.scatter(x,y);
plt.plot(x,mymodel);
plt.show()

# %% [markdown]
# Analysis Of r-value

# %%
print(r)
# Out:
# -0.758591524376155

# %% [markdown]
# Future Predictions:

# %%
res=myfunc(10)
print(res)

res=myfunc(20)
print(res)

res=myfunc(40)
print(res)
# Out:
# 85.59308314937454
# 68.08020603384843
# 33.054451802796194

# %% [markdown]
# Polynomial Regression:

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

plt.scatter(x,y)

# %%
mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

myline = numpy.linspace(1, 22, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %% [markdown]
# r2 Value Analysis:

# %%
print(r2_score(y, mymodel(x)));
# Out:
# 0.9432150416451025

# %% [markdown]
# Predicting Future Values:

# %%
res=mymodel(10)
print(res)

res=mymodel(20)
print(res)

res=mymodel(30)
print(res)
# Out:
# 62.39730982562982
# 97.76768832747516
# 37.95389510181967

# %% [markdown]
# Mulltiple Regression:

# %%
#importing a new dataset 'Cars':

df=pd.read_csv('C:\\Users\\devdi\\Documents\\DISHAN\\cars.csv')

# %%
df.head()
# Out:
#           Car       Model  Volume  Weight  CO2
# 0      Toyoty        Aygo    1000     790   99
# 1  Mitsubishi  Space Star    1200    1160   95
# 2       Skoda      Citigo    1000     929   95
# 3        Fiat         500     900     865   90
# 4        Mini      Cooper    1500    1140  105

# %%
df.tail(10)
# Out:
#          Car    Model  Volume  Weight  CO2
# 26      Audi       A4    2000    1490  104
# 27      Audi       A6    2000    1725  114
# 28     Volvo      V70    1600    1523  109
# 29       BMW        5    2000    1705  114
# 30  Mercedes  E-Class    2100    1605  115
# 31     Volvo     XC70    2000    1746  117
# 32      Ford    B-Max    1600    1235  104
# 33       BMW      216    1600    1390  108
# 34      Opel   Zafira    1600    1405  109
# 35  Mercedes      SLK    2500    1395  120

# %%
x=df[['Weight','Volume']]
y=df['CO2']

# %%
regr = linear_model.LinearRegression()
regr.fit(x,y);

# %% [markdown]
# Predicting a future value based on 2 value inputs:

# %%
res=regr.predict([[2300,1300]])
print(res)
# Out:
# [107.2087328]

# %% [markdown]
# Checking Coefficient Value:

# %%
print(regr.coef_)
# Out:
# [0.00755095 0.00780526]

# %% [markdown]
# Train-Test Split On Datasets:

# %%
x=df[['Weight']]
y=df['CO2']
plt.scatter(x,y);
plt.show();

# %%
#splitting data set into 80(Train):20(Test)
train_x = x[:80]
train_y = y[:80]

test_x = x[80:]
test_y = y[80:]

plt.scatter(train_x,train_y);
plt.show();

# %%
# building a polynomial regression model on the train data-set:

import numpy
from sklearn.metrics import r2_score
numpy.random.seed(2)

x = numpy.random.normal(3, 1, 100)
y = numpy.random.normal(150, 40, 100) / x

train_x = x[:80]
train_y = y[:80]

test_x = x[80:]
test_y = y[80:]

mymodel = numpy.poly1d(numpy.polyfit(train_x, train_y, 4))

r2 = r2_score(train_y, mymodel(train_x))

print(r2)
# Out:
# 0.7988645544629797

# %%
# Now checking r2 score using test dataset:

r2 = r2_score(test_y, mymodel(test_x))

print(r2)
# Out:
# 0.8086921460343581
